# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-15c7129d04f9> in <module>
#      12
#      13 # Incorporated citipy to determine city based on latitude and longitude
# ---> 14 from citipy import citipy
#      15
#      16 # Output File (CSV)
#
# ModuleNotFoundError: No module named 'citipy'

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={api_key}&units={units}&q="
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9674f5ed56ca> in <module>
#      10 # Identify nearest city for each lat, lng combination
#      11 for lat_lng in lat_lngs:
# ---> 12     city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#      13
#      14     # If the city is unique, then add it to a our cities list
#
# NameError: name 'citipy' is not defined

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
temp = []
humidity = []
cloudiness = []
wind_speed = []
city_list = []
country = []
date = []
lat = []
lng = []

units = "imperial"
#check it works for one
city_trial = "London"
# Build partial query URL
query_url = f"{base_url}appid={api_key}&units={units}&q="
#this helps you locate what you want to append into the other lists
data = requests.get(query_url + city_trial).json()
pprint(data)


for city in cities:
    print(f"Processing request for {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        city_list.append(response['name'])
        
    except (KeyError,IndexError):
        print(f"no information gathered for {city}. Skipping")
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 51.51, 'lon': -0.13},
#  'dt': 1553470015,
#  'id': 2643743,
#  'main': {'humidity': 65,
#           'pressure': 1029,
#           'temp': 44.04,
#           'temp_max': 46.99,
#           'temp_min': 41},
#  'name': 'London',
#  'sys': {'country': 'GB',
#          'id': 1413,
#          'message': 0.0071,
#          'sunrise': 1553406896,
#          'sunset': 1553451526,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 290, 'speed': 8.05}}
# Processing request for berlevag
# Processing request for punta arenas
# Processing request for bathsheba
# Processing request for kayes
# Processing request for vardo
# Processing request for qaanaaq
# Processing request for jamestown
# Processing request for namibe
# Processing request for port elizabeth
# Processing request for bluff
# Processing request for chuy
# Processing request for lakes entrance
# Processing request for ushuaia
# Processing request for skala
# Processing request for bunia
# Processing request for koboldo
# no information gathered for koboldo. Skipping
# Processing request for barrow
# Processing request for luderitz
# Processing request for chumikan
# Processing request for tuatapere
# Processing request for nuuk
# Processing request for alofi
# Processing request for cidreira
# Processing request for ribeira grande
# Processing request for klaksvik
# Processing request for sentyabrskiy
# no information gathered for sentyabrskiy. Skipping
# Processing request for at-bashi
# Processing request for hilo
# Processing request for hasaki
# Processing request for taolanaro
# no information gathered for taolanaro. Skipping
# Processing request for mataura
# Processing request for auki
# Processing request for comodoro rivadavia
# Processing request for yellowknife
# Processing request for constitucion
# Processing request for pisco
# Processing request for bihariganj
# Processing request for ushirombo
# Processing request for illoqqortoormiut
# no information gathered for illoqqortoormiut. Skipping
# Processing request for yumen
# Processing request for mikuni
# Processing request for camopi
# Processing request for kodiak
# Processing request for flinders
# Processing request for albany
# Processing request for bayangol
# Processing request for nizhneyansk
# no information gathered for nizhneyansk. Skipping
# Processing request for alyangula
# Processing request for belushya guba
# no information gathered for belushya guba. Skipping
# Processing request for pochutla
# Processing request for basoko
# Processing request for attawapiskat
# no information gathered for attawapiskat. Skipping
# Processing request for presidente epitacio
# Processing request for pa sang
# Processing request for saldanha
# Processing request for fuerte olimpo
# Processing request for chaiyaphum
# Processing request for maniitsoq
# Processing request for yerbogachen
# Processing request for boa vista
# Processing request for nikolskoye
# Processing request for lebu
# Processing request for egvekinot
# Processing request for hofn
# Processing request for port alfred
# Processing request for bethel
# Processing request for rawah
# no information gathered for rawah. Skipping
# Processing request for touros
# Processing request for mys shmidta
# no information gathered for mys shmidta. Skipping
# Processing request for new norfolk
# Processing request for savannah bight
# Processing request for portland
# Processing request for busselton
# Processing request for we
# no information gathered for we. Skipping
# Processing request for saint-francois
# Processing request for dali
# Processing request for vaitupu
# no information gathered for vaitupu. Skipping
# Processing request for olonets
# Processing request for carnarvon
# Processing request for kavaratti
# Processing request for hermanus
# Processing request for abu samrah
# Processing request for lakeway
# Processing request for georgetown
# Processing request for myitkyina
# Processing request for tual
# Processing request for bredasdorp
# Processing request for lagoa
# Processing request for gold coast
# Processing request for paamiut
# Processing request for rikitea
# Processing request for buariki
# no information gathered for buariki. Skipping
# Processing request for puerto ayora
# Processing request for el dorado
# Processing request for fairbanks
# Processing request for kendari
# Processing request for darnah
# Processing request for hobart
# Processing request for sakaiminato
# Processing request for wulanhaote
# no information gathered for wulanhaote. Skipping
# Processing request for laguna de perlas
# Processing request for hamilton
# Processing request for saskylakh
# Processing request for hithadhoo
# Processing request for jatai
# Processing request for tiksi
# Processing request for baghdad
# Processing request for provideniya
# Processing request for luxeuil-les-bains
# Processing request for saint george
# Processing request for wanaka
# Processing request for pangody
# Processing request for airai
# Processing request for vaini
# Processing request for port augusta
# Processing request for denpasar
# Processing request for tumannyy
# no information gathered for tumannyy. Skipping
# Processing request for saint-philippe
# Processing request for pitkyaranta
# Processing request for zhangjiakou
# Processing request for dikson
# Processing request for bonthe
# Processing request for mahebourg
# Processing request for novikovo
# Processing request for hay river
# Processing request for derzhavinsk
# Processing request for samusu
# no information gathered for samusu. Skipping
# Processing request for galle
# Processing request for sao joao da barra
# Processing request for tirumullaivasal
# Processing request for avarua
# Processing request for la ronge
# Processing request for marawi
# Processing request for tabiauea
# no information gathered for tabiauea. Skipping
# Processing request for kingsport
# Processing request for maceio
# Processing request for phetchaburi
# Processing request for zhigansk
# Processing request for dunedin
# Processing request for butaritari
# Processing request for ijaki
# no information gathered for ijaki. Skipping
# Processing request for candolim
# Processing request for dzhusaly
# no information gathered for dzhusaly. Skipping
# Processing request for beaupre
# Processing request for banda aceh
# Processing request for saint anthony
# Processing request for upernavik
# Processing request for ohaeawai
# Processing request for kungurtug
# Processing request for codrington
# Processing request for palma del rio
# Processing request for warqla
# no information gathered for warqla. Skipping
# Processing request for sur
# Processing request for lexington park
# Processing request for karauzyak
# no information gathered for karauzyak. Skipping
# Processing request for sitka
# Processing request for khatanga
# Processing request for juruti
# Processing request for shache
# Processing request for castro
# Processing request for vokhma
# Processing request for buin
# Processing request for kapaa
# Processing request for zamora
# Processing request for megion
# Processing request for stromness
# Processing request for manacapuru
# Processing request for acoua
# Processing request for de-kastri
# Processing request for ahipara
# Processing request for caxito
# Processing request for ambon
# Processing request for coracao de jesus
# Processing request for dingle
# Processing request for te anau
# Processing request for bandarbeyla
# Processing request for nerchinskiy zavod
# Processing request for arraial do cabo
# Processing request for bouca
# Processing request for crab hill
# no information gathered for crab hill. Skipping
# Processing request for bowen
# Processing request for victoria
# Processing request for tuktoyaktuk
# Processing request for lamar
# Processing request for rungata
# no information gathered for rungata. Skipping
# Processing request for kenai
# Processing request for umzimvubu
# no information gathered for umzimvubu. Skipping
# Processing request for cockburn harbour
# no information gathered for cockburn harbour. Skipping
# Processing request for tasiilaq
# Processing request for paradwip
# no information gathered for paradwip. Skipping
# Processing request for bambous virieux
# Processing request for tezu
# Processing request for norman wells
# Processing request for salalah
# Processing request for hot springs
# Processing request for elizabeth city
# Processing request for roald
# Processing request for pevek
# Processing request for nishihara
# Processing request for inderborskiy
# no information gathered for inderborskiy. Skipping
# Processing request for saryshagan
# no information gathered for saryshagan. Skipping
# Processing request for udaipur
# Processing request for borogontsy
# Processing request for prainha
# Processing request for pangai
# Processing request for zmievka
# no information gathered for zmievka. Skipping
# Processing request for shelburne
# Processing request for tazovskiy
# Processing request for tateyama
# Processing request for quelimane
# Processing request for waingapu
# Processing request for ponta do sol
# Processing request for manggar
# Processing request for chongqing
# Processing request for belmonte
# Processing request for aklavik
# Processing request for qaqortoq
# Processing request for east london
# Processing request for skelleftea
# Processing request for kholodnyy
# Processing request for sao paulo do potengi
# Processing request for eau claire
# Processing request for taoudenni
# Processing request for mikhaylovka
# Processing request for belaya gora
# Processing request for singaparna
# Processing request for zemetchino
# Processing request for cumberland
# Processing request for isangel
# Processing request for cascais
# Processing request for thompson
# Processing request for acarau
# no information gathered for acarau. Skipping
# Processing request for cabo san lucas
# Processing request for iberia
# Processing request for jardim
# Processing request for kavieng
# Processing request for duncan
# Processing request for katsuura
# Processing request for san quintin
# Processing request for port hardy
# Processing request for gurgan
# no information gathered for gurgan. Skipping
# Processing request for moron
# Processing request for kiama
# Processing request for itoman
# Processing request for ortigueira
# Processing request for atuona
# Processing request for antonina
# Processing request for sisimiut
# Processing request for luganville
# Processing request for chokurdakh
# Processing request for hailar
# Processing request for sierra vista
# Processing request for ornskoldsvik
# Processing request for san rafael
# Processing request for terrak
# Processing request for lorengau
# Processing request for andenes
# no information gathered for andenes. Skipping
# Processing request for barbar
# no information gathered for barbar. Skipping
# Processing request for hunza
# no information gathered for hunza. Skipping
# Processing request for nata
# Processing request for eenhana
# Processing request for whitehorse
# Processing request for juifang
# no information gathered for juifang. Skipping
# Processing request for bonavista
# Processing request for mao
# Processing request for strezhevoy
# Processing request for souillac
# Processing request for sorvag
# no information gathered for sorvag. Skipping
# Processing request for englehart
# Processing request for chegdomyn
# Processing request for esperance
# Processing request for narsaq
# Processing request for hami
# Processing request for tabuk
# Processing request for saint-pierre
# Processing request for geraldton
# Processing request for sangod
# Processing request for hun
# Processing request for meulaboh
# Processing request for anar darreh
# no information gathered for anar darreh. Skipping
# Processing request for rawson
# Processing request for teeli
# Processing request for cayenne
# Processing request for chernoyerkovskaya
# Processing request for iqaluit
# Processing request for danville
# Processing request for nguiu
# no information gathered for nguiu. Skipping
# Processing request for motygino
# Processing request for lovington
# Processing request for santiago
# Processing request for puerto escondido
# Processing request for san juan de los morros
# Processing request for sao filipe
# Processing request for barcelos
# Processing request for dordrecht
# Processing request for southbridge
# Processing request for atikokan
# Processing request for zhanaozen
# Processing request for porto tolle
# Processing request for sept-iles
# Processing request for grand river south east
# no information gathered for grand river south east. Skipping
# Processing request for nanortalik
# Processing request for antropovo
# Processing request for cape town
# Processing request for yining
# Processing request for zhezkazgan
# Processing request for clyde river
# Processing request for pangnirtung
# Processing request for tashtyp
# Processing request for rio gallegos
# Processing request for illapel
# Processing request for kadyy
# Processing request for usinsk
# Processing request for baiyin
# Processing request for usogorsk
# Processing request for olinda
# Processing request for gizo
# Processing request for eureka
# Processing request for celestun
# Processing request for amderma
# no information gathered for amderma. Skipping
# Processing request for baltasi
# Processing request for la uribe
# no information gathered for la uribe. Skipping
# Processing request for salvador
# Processing request for mpulungu
# Processing request for haines junction
# Processing request for bardiyah
# no information gathered for bardiyah. Skipping
# Processing request for saint-georges
# Processing request for hammerfest
# Processing request for port keats
# Processing request for guerrero negro
# Processing request for teterow
# Processing request for durban
# Processing request for srednekolymsk
# Processing request for chicama
# Processing request for poltavka
# Processing request for emba
# Processing request for kumluca
# Processing request for samalaeulu
# no information gathered for samalaeulu. Skipping
# Processing request for omboue
# Processing request for kahului
# Processing request for kupang
# Processing request for gigmoto
# Processing request for seoul
# Processing request for okhotsk
# Processing request for tsihombe
# no information gathered for tsihombe. Skipping
# Processing request for monrovia
# Processing request for bargal
# no information gathered for bargal. Skipping
# Processing request for candelaria
# Processing request for tura
# Processing request for grindavik
# Processing request for asuncion
# Processing request for aksha
# Processing request for yeppoon
# Processing request for mikkeli
# Processing request for emerald
# Processing request for svetlogorsk
# Processing request for inhambane
# Processing request for jasa tomic
# Processing request for mudgee
# Processing request for fallon
# Processing request for longyearbyen
# Processing request for jutiquile
# Processing request for whyalla
# Processing request for tanjong tokong
# no information gathered for tanjong tokong. Skipping
# Processing request for laiyang
# Processing request for charters towers
# Processing request for eyl
# Processing request for kaitangata
# Processing request for krasnoselkup
# no information gathered for krasnoselkup. Skipping
# Processing request for husavik
# Processing request for honavar
# Processing request for kruisfontein
# Processing request for listvyanka
# Processing request for saleaula
# no information gathered for saleaula. Skipping
# Processing request for ciamis
# Processing request for vila franca do campo
# Processing request for temaraia
# no information gathered for temaraia. Skipping
# Processing request for mancio lima
# no information gathered for mancio lima. Skipping
# Processing request for seydi
# Processing request for bilibino
# Processing request for barra patuca
# Processing request for kangasala
# Processing request for chabahar
# Processing request for aksay
# Processing request for faanui
# Processing request for lolua
# no information gathered for lolua. Skipping
# Processing request for magadan
# Processing request for formoso do araguaia
# no information gathered for formoso do araguaia. Skipping
# Processing request for shumikha
# Processing request for hobyo
# Processing request for bacabal
# Processing request for pinotepa nacional
# no information gathered for pinotepa nacional. Skipping
# Processing request for raigarh
# Processing request for ismailia
# Processing request for araouane
# Processing request for desbiens
# Processing request for mahibadhoo
# Processing request for sayyan
# Processing request for verkhnevilyuysk
# Processing request for ko samui
# Processing request for chapais
# Processing request for marcona
# no information gathered for marcona. Skipping
# Processing request for kieta
# Processing request for buala
# Processing request for dudinka
# Processing request for yanam
# Processing request for gerash
# Processing request for nabire
# Processing request for shieli
# Processing request for kozachi laheri
# Processing request for rock sound
# Processing request for rocha
# Processing request for mitsamiouli
# Processing request for suez
# Processing request for cookeville
# Processing request for padang
# Processing request for westport
# Processing request for cherskiy
# Processing request for elk plain
# Processing request for jomalig
# no information gathered for jomalig. Skipping
# Processing request for ugoofaaru
# Processing request for tawkar
# no information gathered for tawkar. Skipping
# Processing request for santo nino
# Processing request for asayita
# no information gathered for asayita. Skipping
# Processing request for alto longa
# Processing request for grand forks
# Processing request for santa ana
# Processing request for deer lake
# Processing request for bois-guillaume
# Processing request for torbay
# Processing request for nhulunbuy
# Processing request for tungkang
# no information gathered for tungkang. Skipping
# Processing request for heihe
# Processing request for lufilufi
# Processing request for yulara
# Processing request for aguie
# Processing request for hambantota
# Processing request for niono
# Processing request for barentsburg
# no information gathered for barentsburg. Skipping
# Processing request for denizli
# Processing request for lompoc
# Processing request for orumiyeh
# Processing request for socorro
# Processing request for yazman
# Processing request for san cristobal
# Processing request for mareeba
# Processing request for blagoyevo
# Processing request for davila
# Processing request for olavarria
# Processing request for aflu
# no information gathered for aflu. Skipping
# Processing request for evensk
# Processing request for florianopolis
# Processing request for mullaitivu
# no information gathered for mullaitivu. Skipping
# Processing request for birao
# Processing request for caravelas
# Processing request for barawe
# no information gathered for barawe. Skipping
# Processing request for ushumun
# Processing request for omsukchan
# Processing request for sorland
# Processing request for talas
# Processing request for vila velha
# Processing request for rujewa
# Processing request for bambanglipuro
# Processing request for bengkulu
# no information gathered for bengkulu. Skipping
# Processing request for gombong
# Processing request for leningradskiy
# Processing request for kalmunai
# Processing request for necochea
# Processing request for tongren
# Processing request for kisangani
# Processing request for constantine
# Processing request for los llanos de aridane
# Processing request for wewak
# Processing request for bull savanna
# Processing request for ntoum
# Processing request for mandalgovi
# Processing request for richards bay
# Processing request for kloulklubed
# Processing request for nizhniy chir
# Processing request for olsztyn
# Processing request for kathmandu
# Processing request for santarem
# no information gathered for santarem. Skipping
# Processing request for tillabery
# no information gathered for tillabery. Skipping
# Processing request for ifanadiana
# Processing request for vaitape
# Processing request for tilichiki
# Processing request for henties bay
# Processing request for high level
# Processing request for channel-port aux basques
# Processing request for sao sepe
# Processing request for adoni
# Processing request for ruatoria
# no information gathered for ruatoria. Skipping
# Processing request for kaduy
# Processing request for udachnyy
# Processing request for plettenberg bay
# Processing request for mecca
# Processing request for tombouctou
# Processing request for mago
# Processing request for ostrovnoy
# Processing request for guanare
# Processing request for kachikau
# no information gathered for kachikau. Skipping
# Processing request for bubaque
# Processing request for goderich
# Processing request for ocoee
# Processing request for fukue
# Processing request for stelle
# Processing request for louisbourg
# no information gathered for louisbourg. Skipping
# Processing request for tunduru
# no information gathered for tunduru. Skipping
# Processing request for noyabrsk
# Processing request for bibiani
# Processing request for katobu
# Processing request for severo-kurilsk
# Processing request for pleshanovo
# Processing request for mar del plata
# Processing request for gorele
# Processing request for scarborough
# Processing request for kefamenanu
# Processing request for bolonchen
# no information gathered for bolonchen. Skipping
# Processing request for mamburao
# Processing request for cururupu
# Processing request for lasa
# Processing request for natal
# Processing request for jijiga
# Processing request for alugan
# Processing request for khani
# Processing request for yaan
# Processing request for kondinskoye
# Processing request for pacific grove
# Processing request for tatsinskaya
# no information gathered for tatsinskaya. Skipping
# Processing request for palabuhanratu
# no information gathered for palabuhanratu. Skipping
# Processing request for kalomo
# no information gathered for kalomo. Skipping
# Processing request for kolosovka
# Processing request for mahajanga
# Processing request for karatsu
# Processing request for bhadasar
# Processing request for beloha
# Processing request for turukhansk
# Processing request for kalabo
# Processing request for dinsor
# no information gathered for dinsor. Skipping
# Processing request for marsa matruh
# Processing request for laohekou
# Processing request for mount gambier
# Processing request for peniche
# Processing request for pokhara
# Processing request for darovskoy
# Processing request for williamsport
# Processing request for havre
# Processing request for tezpur
# Processing request for oksfjord
# Processing request for angoche
# Processing request for shanghai
# Processing request for san carlos de bariloche
# Processing request for kunming
# Processing request for burnie
# Processing request for ascension
# no information gathered for ascension. Skipping
# Processing request for khajuraho
# Processing request for atasu
# Processing request for ariquemes
# Processing request for kothapet
# Processing request for galesong
# Processing request for vakhtan
# Processing request for jalpan
# Processing request for jalu
# Processing request for sijunjung
# Processing request for kampene
# Processing request for champerico
# Processing request for mama
# Processing request for guarapari
# Processing request for palu
# Processing request for port macquarie
# Processing request for gzhatsk
# no information gathered for gzhatsk. Skipping
# Processing request for north platte
# Processing request for halalo
# no information gathered for halalo. Skipping
# Processing request for rondonopolis
# Processing request for tyrma
# Processing request for tatvan
# Processing request for lavrentiya
# Processing request for columbus
# Processing request for menongue
# Processing request for saiha
# Processing request for najran
# Processing request for lakselv
# Processing request for puerto carreno
# Processing request for dicabisagan
# Processing request for asosa
# Processing request for novyy urgal
# Processing request for eldikan
# no information gathered for eldikan. Skipping
# Processing request for saint-leu
# Processing request for molteno
# Processing request for hirara
# Processing request for moose factory
# Processing request for fortuna
# Processing request for hualmay
# Processing request for rongcheng
# Processing request for shingu
# Processing request for margate
# Processing request for deputatskiy
# Processing request for qom
# Processing request for joplin
# Processing request for broome
# Processing request for bassar
# Processing request for cuiluan
# Processing request for loandjili
# Processing request for quatre cocos
# Processing request for pasni
# Processing request for beyneu
# Processing request for sola
# Processing request for port hedland
# Processing request for north bend
# Processing request for muros
# Processing request for znamenskoye
# Processing request for wamba
# Processing request for toliary
# no information gathered for toliary. Skipping
# Processing request for lucelia
# Processing request for roswell
# Processing request for sulangan
# Processing request for horta
# Processing request for ust-nera
# Processing request for tidore
# no information gathered for tidore. Skipping
# Processing request for donskoye

# %%
#create the dictionary
weather_dict = {
    "City": city_list,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Max Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind_speed
}
#convert timestamp to actual date
# weather_data["Date"]=weather_data["Date"].astype(int)
# weather_dict['Date'] = pd.to_datetime(weather_dict['Date'], unit='s')
# weather_dict["Date"]=datetime.utcfromtimestamp(weather_dict["Date"]).strftime('%Y-%m-%d %H:%M:%S')

weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Max Temp    Lat  \
# 0      Berlevag          64      NO  03/24/2019       100     28.11  70.86
# 1  Punta Arenas          68      CL  03/24/2019        57     51.80 -53.16
# 2     Bathsheba          75      BB  03/24/2019        83     77.00  13.22
# 3         Kayes          48      ML  03/24/2019        41     84.45  14.44
# 4         Vardo           1      US  03/24/2019        18     62.60  39.62
#
#      Lng  Wind Speed
# 0  29.09       17.47
# 1 -70.91       21.92
# 2 -59.52       14.99
# 3 -11.44        7.63
# 4 -77.74        3.36

# %%
#write to csv file
weather_data.to_csv(output_data_file)

# %%
#create a scatterplot of latitude vs. temperature
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], color="c",
           edgecolors = "blue", s = 40)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (f)")
plt.title("Latitude vs. Maximum Temperature (March 24th, 2018)")
plt.savefig("images/latitude_max-temp")

# %%
#create a scatterplot of latitude vs. Humidity
plt.scatter(weather_data["Lat"], weather_data["Humidity"], color="c",
           edgecolors = "blue", s = 40)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title("Latitude vs. Humidity (March 24th, 2018)")
plt.savefig("images/latitude_humidity")

# %%
#create a scatterplot of latitude vs. Cloudiness
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], color="c",
           edgecolors = "blue", s = 40)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title("Latitude vs. Cloudiness (March 24th, 2018)")
plt.savefig("images/latitude_cloudiness")

# %%
#create a scatterplot of latitude vs. Cloudiness
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], color="c",
           edgecolors = "blue", s = 40)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Latitude vs. Wind Speed (March 24th, 2018)")
plt.savefig("images/latitude_wind-speed")

# %% [markdown]
# Analysis:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c944f0bdad87> in <module>
# ----> 1 print(query_url)
#
# NameError: name 'query_url' is not defined
